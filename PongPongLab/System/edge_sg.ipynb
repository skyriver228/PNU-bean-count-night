# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# - data

# %%
input_img1 = "../../Open/t01/5.jpg"
input_img2 = "../../Open/t01/2.jpg"

# %% [markdown]
# - sovel

# %%
src1=cv2.imread(input_img1)
gray1=cv2.cvtColor(src1,cv2.COLOR_BGR2GRAY)
plt.imshow(gray1)

# %%
src2=cv2.imread(input_img2)
plt.imshow(src2)

# %%
dx=cv2.Sobel(src1,cv2.CV_32F,1,0)
dy=cv2.Sobel(src1,cv2.CV_32F,0,1)

# %%
mag=cv2.magnitude(dx,dy)
mag=np.clip(mag,0,255).astype(np.uint8)
plt.imshow(mag)

# %%
dx=cv2.Sobel(src,-1,1,0,delta=128)
dy=cv2.Sobel(src,-1,0,1,delta=128)
plt.imshow(dx)

# %%
plt.imshow(dy)

# %% [markdown]
# - Sharr

# %%
dx=cv2.Scharr(src,-1,1,0,delta=128)
plt.imshow(dx)

# %%
dy=cv2.Sobel(src,-1,0,1,delta=128)
plt.imshow(dy)

# %%
src=cv2.imread(input_img1,cv2.IMREAD_GRAYSCALE)
dx=cv2.Sobel(src,cv2.CV_32F,1,0)
dy=cv2.Sobel(src,cv2.CV_32F,0,1)
mag=cv2.magnitude(dx,dy)
mag=np.clip(mag,0,255).astype(np.uint8)
dst=np.zeros(src.shape[:2],np.uint8)
dst[mag>120]=255
_,dst=cv2.threshold(mag,120,255,cv2.THRESH_BINARY)
plt.imshow(dst)

# %% [markdown]
# - canny

# %%
dst=cv2.Canny(src,50,150)
plt.imshow(dst)
